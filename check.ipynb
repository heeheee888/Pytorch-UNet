# %%
! python3 overlap.py
# Out:
# Figure(640x480)

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import os
import numpy as np
import cv2
import os
import glob

# path = './test/*'
# file_list = os.listdir(path)
file_list = glob.glob('./test/*.png')
# file_list = './test/*.png'
for filename in file_list:

    img = cv2.imread(filename)
    mask = cv2.imread(f'./test/mask/{filename[7:-4]}.png')

    plt.imshow(img)
    plt.imshow(mask[:,:,0], cmap = 'seismic', alpha = 0.2, vmin = -500, vmax = 500) 
    #plt.rcParams["figure.figsize"] = (13, 15)
    plt.axis('off')
    #plt.show()
#     fig.axes.get_xaxis().set_visible(False)
#     fig.axes.get_yaxis().set_visible(False)
    plt.savefig(f'./overlap_ori/{filename[7:-4]}_overlap_ori.png',pad_inches=0)

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import os
import numpy as np
import cv2
import os
import glob

# path = './test/*'
# file_list = os.listdir(path)
file_list = glob.glob('./test/*.png')
# file_list = './test/*.png'
for filename in file_list:

    img = cv2.imread(filename)
    mask = cv2.imread(f'./test/result4/{filename[7:-4]}_OUT.png')

    plt.imshow(img)
    plt.imshow(mask[:,:,0], cmap = 'seismic', alpha = 0.2, vmin = -500, vmax = 500) 
    #plt.rcParams["figure.figsize"] = (13, 15)
    plt.axis('off')
    #plt.show()
    plt.savefig(f'./overlap_train/{filename[7:-4]}_overlap_train.png')
